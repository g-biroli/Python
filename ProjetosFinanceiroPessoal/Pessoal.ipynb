# %%
#Importando o Pandas para ler a planilha do Google Sheets
import pandas as pd

#ID da planilha do Google Sheets
#Acesso a planilha em formato CSV
sheet_id = "1xBK4KHEh5QcT9Wwzt6icTAlrJiccNMNXBuaYjhiQVJY"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"


#Lendo a planilha do Google Sheets usando o Pandas
df_investimentos = pd.read_csv(url)
df_investimentos['Investimento Total'] = df_investimentos['Aporte'].sum()
print(df_investimentos.head())


##Ajustar a questão da tabela de investimento total
##Quero somar fundo a fundo, de acordo com o nome do fundo
##Calcular o rendimento da carteira em %, de acordo com o aporte total mês e o rendimento final do mês. (Fazer uma coluna com a % de rendimento mensal)
# Out:
#                                                Fundo      Aporte       Data  \
# 0  Western Asset Total Credit Advisory FIC de FIF...    R$500,00  7/01/2026
# 1  XP Debêntures Incentivadas CDI CP FIF Incentiv...  R$3.000,00  7/01/2026
# 2        V8 Speedway Long Short FIF FIF Multimercado  R$1.000,00  7/01/2026
# 3  Western Asset Total Credit Advisory FIC de FIF...    R$700,00  5/03/2026
# 4  XP Debêntures Incentivadas CDI CP FIF Incentiv...  R$1.000,00  6/04/2026
#
#                   Objetivo                              Investimento Total
# 0    RESERVA DE EMERGÊNCIA  R$500,00R$3.000,00R$1.000,00R$700,00R$1.000,00
# 1  INVESTIMETO LONGO PRAZO  R$500,00R$3.000,00R$1.000,00R$700,00R$1.000,00
# 2  INVESTIMETO LONGO PRAZO  R$500,00R$3.000,00R$1.000,00R$700,00R$1.000,00
# 3    RESERVA DE EMERGÊNCIA  R$500,00R$3.000,00R$1.000,00R$700,00R$1.000,00
# 4  INVESTIMETO LONGO PRAZO  R$500,00R$3.000,00R$1.000,00R$700,00R$1.000,00
