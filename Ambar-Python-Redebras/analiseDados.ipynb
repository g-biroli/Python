# %%
import pandas as pd

# %%
data = {'Classe': ['Júnior', 'Júnior', 'Pleno', 'Pleno', 'Sênior', 'Sênior'],
        'Nome': ['Alice', 'Bob', 'Charlie', 'David','Gabriel','Heloisa'],
        'Venda': [200,120,340,124,243,350]}

df= pd.DataFrame(data)

# %%
df
# Out:
#    Classe     Nome  Venda
# 0  Júnior    Alice    200
# 1  Júnior      Bob    120
# 2   Pleno  Charlie    340
# 3   Pleno    David    124
# 4  Sênior  Gabriel    243
# 5  Sênior  Heloisa    350

# %%
experiencia = df.groupby("Classe")

# %%
experiencia.sum()
# Out:
#                   Nome  Venda
# Classe
# Júnior        AliceBob    320
# Pleno     CharlieDavid    464
# Sênior  GabrielHeloisa    593

# %%
df.groupby('Classe').sum()
# Out:
#                   Nome  Venda
# Classe
# Júnior        AliceBob    320
# Pleno     CharlieDavid    464
# Sênior  GabrielHeloisa    593

# %%
df.groupby('Classe').max()
# Out:
#            Nome  Venda
# Classe
# Júnior      Bob    200
# Pleno     David    340
# Sênior  Heloisa    350

# %%
df.query("Classe == 'Júnior' and Venda > 100")
# Out:
# Empty DataFrame
# Columns: [Classe, Nome, Venda]
# Index: []
