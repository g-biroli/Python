# %%
#INFORMAÇÕES PRINCIPAIS DA ANALISE

import pandas as pd
import numpy as np

#Criando a fonte dos dados
caminho_dados = r"Z:\Comercial\GABRIEL - E-COMMERCE\Redebras\Business Analyst\B.I Comercial\3. Analises Março\2026\Base Dados\RelPedidoCli.xls"

#Função para ler os dados
df_comercial = pd.read_excel(caminho_dados)
