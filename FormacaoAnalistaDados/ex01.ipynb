# %%
#INFORMAÇÕES PRINCIPAIS DA ANALISE

import pandas as pd
import numpy as np

caminho_arquivo = r'Z:\Comercial\GABRIEL - E-COMMERCE\Redebras\Business Analyst\B.I Comercial\3. Analises Março\2026\Base Dados\RelPedidoCli.xls'  # Substitua pelo caminho do seu arquivo CSV
df = pd.read_excel(caminho_arquivo)

# %%
df
# Out:
#       PEDIDO  EMP    TIPO        DATA  \
# 0     113532  1.0  PEDIDO  12/02/2026
# 1     114765  1.0  PEDIDO  28/08/2024
# 2     119881  1.0  PEDIDO  06/03/2026
# 3     131379  1.0  PEDIDO  01/10/2025
# 4     144338  1.0  PEDIDO  10/03/2026
# ...      ...  ...     ...         ...
# 1128  231192  1.0  PEDIDO  31/03/2026
# 1129  231193  1.0  PEDIDO  31/03/2026
# 1130  231200  1.0  PEDIDO  31/03/2026
# 1131  231222  1.0  PEDIDO  31/03/2026
# 1132    1132  NaN     NaN         NaN
#
#                                                    NOME    INTEGRAÇÃO   UF  \
# 0                                 ELCO ENGENHARIA LTDA            NaN   PR
# 1                  VIDEIRA TRANSPORTES RODOVIARIOS LTDA           NaN   SP
# 2     SAN SEI PRODUTOS PARA MANUTENCAO PREDIAL E IND...           NaN   SP
# 3     TECMETAL COM DE VALVULAS, TUBOS E CONEXOES IND...           NaN   SP
# 4                                 EUROMON MONTAGENS S/A           NaN   SP
# ...

# %%
df['MKP'] < '25%'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1128    False
# 1129    False
# 1130     True
# 1131     True
# 1132    False
# Name: MKP, Length: 1133, dtype: bool

# %%
df['TOTAL PEDIDO'].max()
# Out:
# np.float64(4229353.369999997)

# %%
df.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.index
#
# NameError: name 'df' is not defined
