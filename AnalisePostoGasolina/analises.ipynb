# %%
# Importação das Bibliotecas Pandas e Sqlite3
import pandas as pd 
import sqlite3

# Criação do DataFrame a partir do arquivo CSV
df_gasolina200 = pd.read_csv('DataBase\gasolina_2000+.csv', sep=',')
df_gasolina200
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0               0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1               1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2               2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3               3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4               4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...           ...          ...         ...           ...                 ...
# 42633       52802   2010-12-26  2011-01-01       SUDESTE      RIO DE JANEIRO
# 42634       52803   2010-12-26  2011-01-01       SUDESTE           SAO PAULO
# 42635       52804   2010-12-26  2011-01-01           SUL              PARANA
# 42636       52805   2010-12-26  2011-01-01           SUL   RIO GRANDE DO SUL
# 42637       52806   2010-12-26  2011-01-01           SUL      SANTA CATARINA
#
# ...
